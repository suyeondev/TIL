# %% [markdown]
# # 데이터 통합
# - 뮤직카우 데이터 통합하기

# %%
# 필요한 라이브러리 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# seaborn lib add
import seaborn as sns

from glob import glob

# %matplotlib inline

import json

import warnings
warnings.filterwarnings(action = 'ignore') 


from datetime import date, datetime, timedelta
from dateutil.parser import parse

print("numpy version:",np.__version__) 
print("pandas version:",pd.__version__)

# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# numpy version: 1.20.1
# pandas version: 1.2.4

# %%
# 전처리할 데이터 불러오기
copyright = pd.read_csv('C:/Users/whgud/TIL/team project/뮤직카우_저작권정보.csv')
musicow =pd.read_csv('C:/Users/whgud/TIL/team project/뮤직카우_가격높은순.csv') 
genie = pd.read_csv('C:/Users/whgud/TIL/team project/musiccow_genie20211021.csv')

# %%
len(genie)
# Out:
# 941

# %%
merged =pd.merge(musicow, copyright, how='inner', on=('title','artist'))
merged
# Out:
#                                                  음원이미지  \
# 0    https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 1    https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 2    https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 3    https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 4    https://d1z4u1c8ot3who.cloudfront.net/song/210...
# ..                                                 ...
# 966  https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 967  https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 968  https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 969  https://d1z4u1c8ot3who.cloudfront.net/song/210...
# 970  https://d1z4u1c8ot3who.cloudfront.net/song/210...
#
#                                                  title  \
# 0                                         롤린 (Rollin')
# 1                      미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)
# 2                                                   축가
# 3                                                 저녁하늘
# ...

# %%
music=pd.merge(merged, genie, how='inner', on=('title','artist'))
music
# Out:
#                                                  음원이미지                title  \
# 0    https://d1z4u1c8ot3who.cloudfront.net/song/210...                   축가
# 1    https://d1z4u1c8ot3who.cloudfront.net/song/210...                눈물 자국
# 2    https://d1z4u1c8ot3who.cloudfront.net/song/210...                   안녕
# 3    https://d1z4u1c8ot3who.cloudfront.net/song/210...                   이름
# 4    https://d1z4u1c8ot3who.cloudfront.net/song/210...          그 중에 그대를 만나
# ..                                                 ...                  ...
# 527  https://d1z4u1c8ot3who.cloudfront.net/song/210...              ANYMORE
# 528  https://d1z4u1c8ot3who.cloudfront.net/song/210...              Tonight
# 529  https://d1z4u1c8ot3who.cloudfront.net/song/210...              Tonight
# 530  https://d1z4u1c8ot3who.cloudfront.net/song/210...  기적 (What about you)
# 531  https://d1z4u1c8ot3who.cloudfront.net/song/210...                   문득
#
# ...

# %%
len(copyright)
# Out:
# 946

# %%
len(copyright)
# Out:
# 946
